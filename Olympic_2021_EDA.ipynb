# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pip install openpyxl

# %%
df_athletes = pd.read_excel('/content/drive/MyDrive/EDA/olympic/Athletes.xlsx')
df_coaches = pd.read_excel('/content/drive/MyDrive/EDA/olympic/Coaches.xlsx')
df_gender =  pd.read_excel('/content/drive/MyDrive/EDA/olympic/EntriesGender.xlsx')
df_medals = pd.read_excel('/content/drive/MyDrive/EDA/olympic/Medals.xlsx')
df_teams = pd.read_excel('/content/drive/MyDrive/EDA/olympic/Teams.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df_athletes.head()
# Out:
#                 Name     NOC           Discipline
# 0    AALERUD Katrine  Norway         Cycling Road
# 1        ABAD Nestor   Spain  Artistic Gymnastics
# 2  ABAGNALE Giovanni   Italy               Rowing
# 3     ABALDE Alberto   Spain           Basketball
# 4      ABALDE Tamara   Spain           Basketball

# %%
df_athletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11085 entries, 0 to 11084
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        11085 non-null  object
#  1   NOC         11085 non-null  object
#  2   Discipline  11085 non-null  object
# dtypes: object(3)
# memory usage: 259.9+ KB

# %%
df_athletes.shape
# Out:
# (11085, 3)

# %%
#which country has the most atheletes
x = df_athletes.NOC.value_counts().index[0:35]
y = df_athletes.NOC.value_counts().values[0:35]
plt.figure(figsize=(20,5))
plt.bar(x,y)
plt.xlabel('country')
plt.ylabel('number of athelets')
plt.xticks(rotation='vertical',size=10)
plt.yticks(size=15)
plt.show()

# %%
x = df_athletes.NOC.value_counts().index[0:35]
x
# Out:
# Index(['United States of America', 'Japan', 'Australia',
#        'People's Republic of China', 'Germany', 'France', 'Canada',
#        'Great Britain', 'Italy', 'Spain', 'ROC', 'Brazil', 'Netherlands',
#        'Republic of Korea', 'New Zealand', 'Poland', 'Argentina',
#        'South Africa', 'Mexico', 'Hungary', 'Ukraine', 'Egypt', 'Sweden',
#        'Belgium', 'India', 'Czech Republic', 'Ireland', 'Switzerland',
#        'Belarus', 'Denmark', 'Turkey', 'Romania', 'Norway', 'Kazakhstan',
#        'Israel'],
#       dtype='object')

# %%
y = df_athletes.NOC.value_counts().values[0:35]
y
# Out:
# array([615, 586, 470, 401, 400, 377, 368, 366, 356, 324, 318, 291, 274,
#        223, 202, 195, 180, 171, 155, 155, 152, 133, 129, 125, 117, 117,
#        116, 115, 104, 103, 102,  99,  92,  92,  85])

# %%
z = df_athletes['NOC'].value_counts()   #this means value count gives index value pairs lol!
z
# Out:
# United States of America       615
# Japan                          586
# Australia                      470
# People's Republic of China     401
# Germany                        400
#                               ...
# United Republic of Tanzania      2
# Saint Kitts and Nevis            2
# Marshall Islands                 2
# Vanuatu                          2
# South Sudan                      2
# Name: NOC, Length: 206, dtype: int64

# %%
#conclusion:- most athelets are from usa(600+) and japan(almost 600)

# %%
# Analysis of discipline column , which is most popular Discipline and which country has the highest participation in it
df_athletes
# Out:
#                         Name      NOC           Discipline
# 0            AALERUD Katrine   Norway         Cycling Road
# 1                ABAD Nestor    Spain  Artistic Gymnastics
# 2          ABAGNALE Giovanni    Italy               Rowing
# 3             ABALDE Alberto    Spain           Basketball
# 4              ABALDE Tamara    Spain           Basketball
# ...                      ...      ...                  ...
# 11080  ZWICKER Martin Detlef  Germany               Hockey
# 11081      ZWOLINSKA Klaudia   Poland         Canoe Slalom
# 11082           ZYKOVA Yulia      ROC             Shooting
# 11083      ZYUZINA Ekaterina      ROC              Sailing
# 11084        ZYZANSKA Sylwia   Poland              Archery
#
# [11085 rows x 3 columns]

# %%
x = df_athletes.Discipline.value_counts().index[0:35]
y = df_athletes.Discipline.value_counts().values[0:35]
plt.figure(figsize=(20,5))
plt.bar(x,y)
plt.xlabel('Discipline')
plt.ylabel('number of athelets')
plt.xticks(rotation='vertical',size=10)
plt.yticks(size=15)
plt.show()

# %%
df_teams.head()
# Out:
#       Name      Discipline                         NOC  Event
# 0  Belgium  3x3 Basketball                     Belgium    Men
# 1    China  3x3 Basketball  People's Republic of China    Men
# 2    China  3x3 Basketball  People's Republic of China  Women
# 3   France  3x3 Basketball                      France  Women
# 4    Italy  3x3 Basketball                       Italy  Women

# %%
df_teams.tail()
# Out:
#               Name  Discipline                       NOC  Event
# 738   South Africa  Water Polo              South Africa  Women
# 739          Spain  Water Polo                     Spain    Men
# 740          Spain  Water Polo                     Spain  Women
# 741  United States  Water Polo  United States of America    Men
# 742  United States  Water Polo  United States of America  Women

# %%
df_teams['Discipline'].value_counts()
# Out:
# Swimming               113
# Athletics               79
# Cycling Track           64
# Archery                 53
# Fencing                 52
# Beach Volleyball        48
# Table Tennis            48
# Artistic Swimming       32
# Football                28
# Artistic Gymnastics     24
# Volleyball              24
# Basketball              24
# Handball                24
# Hockey                  24
# Rugby Sevens            24
# Water Polo              22
# Triathlon               18
# 3x3 Basketball          16
# Rhythmic Gymnastics     14
# Baseball/Softball       12
# Name: Discipline, dtype: int64

# %%
df_athletes = df_teams[(df_teams['Discipline'] == 'Athletics')]
df_athletes['NOC'].value_counts()
# Out:
# United States of America      5
# Germany                       5
# Italy                         5
# Netherlands                   5
# Great Britain                 5
# Jamaica                       5
# Poland                        4
# France                        4
# Trinidad and Tobago           3
# Japan                         3
# Brazil                        3
# Belgium                       3
# Canada                        2
# People's Republic of China    2
# Switzerland                   2
# South Africa                  2
# Nigeria                       2
# India                         2
# Ukraine                       2
# Denmark                       2
# Spain                         1
# Turkey                        1
# Australia                     1
# Ireland                       1
# Bahamas                       1
# Ecuador                       1
# Dominican Republic            1
# Czech Republic                1
# Cuba                          1
# ...

# %%
df_athletes = df_athletes[(df_athletes['Discipline'] == 'Athletics')]
df_athletes['NOC'].value_counts()
# Out:
# United States of America      5
# Germany                       5
# Italy                         5
# Netherlands                   5
# Great Britain                 5
# Jamaica                       5
# Poland                        4
# France                        4
# Trinidad and Tobago           3
# Japan                         3
# Brazil                        3
# Belgium                       3
# Canada                        2
# People's Republic of China    2
# Switzerland                   2
# South Africa                  2
# Nigeria                       2
# India                         2
# Ukraine                       2
# Denmark                       2
# Spain                         1
# Turkey                        1
# Australia                     1
# Ireland                       1
# Bahamas                       1
# Ecuador                       1
# Dominican Republic            1
# Czech Republic                1
# Cuba                          1
# ...

# %%
#Athletics, the most popular discipline, has most participants (5) from the United States, Netherlands, jamaica, Italy , Great Britain and Germany.

# Q:- Which country has highest number of coaches
df_coaches.head()
# Out:
#               Name            NOC  Discipline Event
# 0  ABDELMAGID Wael          Egypt    Football   NaN
# 1        ABE Junya          Japan  Volleyball   NaN
# 2    ABE Katsuhiko          Japan  Basketball   NaN
# 3     ADAMA Cherif  Côte d'Ivoire    Football   NaN
# 4       AGEBA Yuya          Japan  Volleyball   NaN

# %%
df_coaches.shape
# Out:
# (394, 4)

# %%
df_coaches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 394 entries, 0 to 393
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        394 non-null    object
#  1   NOC         394 non-null    object
#  2   Discipline  394 non-null    object
#  3   Event       249 non-null    object
# dtypes: object(4)
# memory usage: 12.4+ KB

# %%
df_coaches['NOC'].value_counts()
#thus we see that japan has the most number of coaches
# Out:
# Japan                       35
# United States of America    28
# Spain                       28
# Australia                   22
# Canada                      16
#                             ..
# Portugal                     1
# Belarus                      1
# Slovakia                     1
# Croatia                      1
# Liechtenstein                1
# Name: NOC, Length: 61, dtype: int64

# %%
df_gender.head()
# Out:
#             Discipline  Female  Male  Total
# 0       3x3 Basketball      32    32     64
# 1              Archery      64    64    128
# 2  Artistic Gymnastics      98    98    196
# 3    Artistic Swimming     105     0    105
# 4            Athletics     969  1072   2041

# %%
df_gender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Discipline  46 non-null     object
#  1   Female      46 non-null     int64
#  2   Male        46 non-null     int64
#  3   Total       46 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.6+ KB

# %%
df_gender.shape
# Out:
# (46, 4)

# %%
df_gender.Male.sum()
# Out:
# 5884

# %%
df_gender.Female.sum()
# Out:
# 5432

# %%
disc = df_gender.groupby('Discipline')
x = list(disc.groups.keys())
female = df_gender.Female
male = df_gender.Male
plt.figure(figsize=(20,8))
X_axis = np.arange(len(x))
plt.bar(X_axis - 0.2 , female, 0.4, label = 'Female')
plt.bar(X_axis + 0.2 , male, 0.4, label = 'Male')
plt.xlabel("Discipline",size=10)
plt.ylabel("Number of Participants")
plt.xticks(X_axis,x,rotation='vertical')
plt.legend()
plt.show()


#There is only one discipline with more females than males which is cycling BMX freestyle. But, females participate in all the disciplines whereas men don't in a couple such as rhythmic gymnastics and artistic swimming

# %%
#Q:- Which country recieved most gold medals? Which recieved most silver and most bronze? Which received least for each?
df_medals.head()
# Out:
#    Rank                    Team/NOC  Gold  Silver  Bronze  Total  \
# 0     1    United States of America    39      41      33    113
# 1     2  People's Republic of China    38      32      18     88
# 2     3                       Japan    27      14      17     58
# 3     4               Great Britain    22      21      22     65
# 4     5                         ROC    20      28      23     71
#
#    Rank by Total
# 0              1
# 1              2
# 2              5
# 3              4
# 4              3

# %%
df_medals.shape
# Out:
# (93, 7)

# %%
df_medals.rename(columns={'Team/NOC':'Teams'}, inplace=True)
x = []
for team in df_medals.Teams:
  x.append(team)
y = df_medals.Gold
plt.figure(figsize=(30,8))
plt.bar(x,y)

for index, value in enumerate(y):
    plt.text(index, value, str(value),color='blue',size=10,fontweight='bold')




plt.xlabel("Country",size=10)
plt.ylabel("Gold Medals")
plt.xticks(x,rotation='vertical',size=15)
plt.title("Gold Medals across Nations")
plt.show()

# %%
df_medals.rename(columns={'Team/NOC':'Teams'}, inplace=True)
x = []
for team in df_medals.Teams:
  x.append(team)
y = df_medals.Silver
plt.figure(figsize=(30,8))
plt.bar(x,y)

for index, value in enumerate(y):
    plt.text(index, value, str(value),color='blue',size=10,fontweight='bold')




plt.xlabel("Country",size=10)
plt.ylabel("Silver medals")
plt.xticks(x,rotation='vertical',size=15)
plt.title("Silver Medals across Nations")
plt.show()

# %%
df_medals.rename(columns={'Team/NOC':'Teams'}, inplace=True)
x = []
for team in df_medals.Teams:
  x.append(team)
y = df_medals.Bronze
plt.figure(figsize=(30,8))
plt.bar(x,y)

for index, value in enumerate(y):
    plt.text(index, value, str(value),color='blue',size=10,fontweight='bold')




plt.xlabel("Country",size=10)
plt.ylabel("Bronze Medals")
plt.xticks(x,rotation='vertical',size=15)
plt.title("Bronze Medals across Nations")
plt.show()
